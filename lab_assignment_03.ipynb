# %% [markdown]
# <a href="https://colab.research.google.com/github/RSK11547210/saikrishna_INFO5502_spring2022/blob/main/lab_assignment_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## The third Lab-assignment (02/10/2022, 50 points in total)

# %% [markdown]
# The purpose of this exercise is to understand users' information needs, then collect data from different sources for analysis.

# %% [markdown]
# Question 1 (10 points). Fomulate your domain problem: Describe an interesting research question (or practical question) you have in mind, what kind of data should be collected to answer the question(s)? How many data needed for the analysis? The detail steps for collecting and save the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):

'''
Please write you answer here:

Research Question:How many number of players has more than 10, 20 and 30 points in the year 2014-2015?

To answer the above research question we need to collect the players complete information for that particluar 
year such the players age,the team he played, number of goals, minutes he played etc. 
As we are planning to find the points scored in the particular year we need to collect the data of the players
for the year 2014-2015.

Collecting and saving the data:
data for this particular research question is collected from web through web scrapping.

1.Need to find the data source for the research question.
2.then we need to copy the address of the url 
3.pull the data from website.
4.we need to import pandas library.
5.need to save the data to a dataframe.

'''

# %% [markdown]
# Question 2 (10 points). Collect your data to answer the research problem: Write python code to collect 1000 data samples you discussed above.

# %%
# You code here (Please add comments in the code):

link="https://www.basketball-reference.com/leagues/NBA_2015_per_game.html"

import pandas as pd 

data_set1=pd.read_html(link)
data_set1
final_data = data_set1[0]

final_data.head(50)
# Out:
#     Rk                 Player  Pos  Age   Tm   G  ...  AST  STL  BLK  TOV   PF   PTS
# 0    1             Quincy Acy   PF   24  NYK  68  ...  1.0  0.4  0.3  0.9  2.2   5.9
# 1    2           Jordan Adams   SG   20  MEM  30  ...  0.5  0.5  0.2  0.5  0.8   3.1
# 2    3           Steven Adams    C   21  OKC  70  ...  0.9  0.5  1.2  1.4  3.2   7.7
# 3    4            Jeff Adrien   PF   28  MIN  17  ...  0.9  0.2  0.5  0.5  1.8   3.5
# 4    5          Arron Afflalo   SG   29  TOT  78  ...  1.7  0.5  0.1  1.5  2.1  13.3
# 5    5          Arron Afflalo   SG   29  DEN  53  ...  1.9  0.6  0.1  1.6  2.0  14.5
# 6    5          Arron Afflalo   SG   29  POR  25  ...  1.1  0.4  0.1  1.3  2.4  10.6
# 7    6          Alexis Ajinça    C   26  NOP  68  ...  0.7  0.3  0.8  1.0  2.2   6.5
# 8    7         Furkan Aldemir   PF   23  PHI  41  ...  0.7  0.4  0.4  0.4  2.3   2.3
# 9    8           Cole Aldrich    C   26  NYK  61  ...  1.2  0.6  1.1  1.0  2.0   5.5
# 10   9      LaMarcus Aldridge   PF   29  POR  71  ...  1.7  0.7  1.0  1.7  1.8  23.4
# 11  10            Lavoy Allen    C   25  IND  63  ...  1.2  0.2  0.7  0.6  1.6   5.0
# 12  11             Tony Allen   SG   33  MEM  63  ...  1.4  2.0  0.5  1.4  2.6   8.6
# 13  12        Al-Farouq Aminu   SF   24  DAL  74  ...  0.8  0.9  0.8  0.7  1.9   5.6
# 14  13           Lou Amundson   PF   32  TOT  53  ...  1.3  0.4  1.0  1.2  2.4   4.9
# 15  13           Lou Amundson   PF   32  CLE  12  ...  0.4  0.1  0.0  0.4  0.9   0.9
# 16  13           Lou Amundson   PF   32  NYK  41  ...  1.6  0.5  1.3  1.4  2.8   6.0
# 17  14         Chris Andersen    C   36  MIA  60  ...  0.7  0.4  1.0  0.7  1.5   5.3
# 18  15          Alan Anderson   SG   32  BRK  74  ...  1.1  0.8  0.1  0.8  2.0   7.4
# 19  16          Kyle Anderson   SF   21  SAS  33  ...  0.8  0.5  0.2  0.3  0.8   2.2
# 20  17          Ryan Anderson   PF   26  NOP  61  ...  0.9  0.5  0.3  1.0  1.9  13.7
# 21  18  Giannis Antetokounmpo   SG   20  MIL  81  ...  2.6  0.9  1.0  2.1  3.1  12.7
# 22  19        Carmelo Anthony   SF   30  NYK  40  ...  3.1  1.0  0.4  2.2  2.2  24.2
# 23  20           Joel Anthony    C   32  DET  49  ...  0.1  0.2  1.0  0.2  1.1   1.8
# 24  Rk                 Player  Pos  Age   Tm   G  ...  AST  STL  BLK  TOV   PF   PTS
# 25  21             Pero Antić    C   32  ATL  63  ...  0.8  0.3  0.2  0.8  2.1   5.7
# 26  22           Trevor Ariza   SF   29  HOU  82  ...  2.5  1.9  0.2  1.7  2.3  12.8
# 27  23         Darrell Arthur   PF   26  DEN  58  ...  1.0  0.8  0.4  0.8  2.5   6.6
# 28  24              Ömer Aşık    C   28  NOP  76  ...  0.9  0.4  0.7  1.3  1.9   7.3
# 29  25          D.J. Augustin   PG   27  TOT  82  ...  4.3  0.6  0.0  1.8  1.1   9.5
# 30  25          D.J. Augustin   PG   27  DET  54  ...  4.9  0.6  0.0  2.0  1.1  10.6
# 31  25          D.J. Augustin   PG   27  OKC  28  ...  3.1  0.6  0.0  1.3  1.1   7.3
# 32  26             Jeff Ayres   PF   27  SAS  51  ...  0.3  0.2  0.2  0.5  1.2   2.7
# 33  27           Luke Babbitt   SF   25  NOP  63  ...  0.4  0.3  0.2  0.4  1.0   4.1
# 34  28       Cameron Bairstow   PF   24  CHI  18  ...  0.1  0.1  0.1  0.2  0.4   0.6
# 35  29        Leandro Barbosa   SG   32  GSW  66  ...  1.5  0.6  0.1  0.7  1.3   7.1
# 36  30             J.J. Barea   PG   30  DAL  77  ...  3.4  0.4  0.0  0.9  1.4   7.5
# 37  31        Andrea Bargnani    C   29  NYK  29  ...  1.6  0.1  0.9  1.4  1.8  14.8
# 38  32        Harrison Barnes   SF   22  GSW  82  ...  1.4  0.7  0.2  0.9  1.8  10.1
# 39  33            Matt Barnes   SF   34  LAC  76  ...  1.5  0.9  0.7  1.1  3.2  10.1
# 40  34            Earl Barron    C   33  PHO  16  ...  0.3  0.3  0.1  0.3  1.6   2.0
# 41  35            Will Barton   SG   24  TOT  58  ...  1.4  0.8  0.3  1.1  1.2   6.8
# 42  35            Will Barton   SG   24  POR  30  ...  0.9  0.5  0.1  0.6  0.7   3.0
# 43  35            Will Barton   SG   24  DEN  28  ...  1.9  1.2  0.5  1.6  1.8  11.0
# 44  36           Brandon Bass   PF   29  BOS  82  ...  1.3  0.5  0.4  1.0  1.7  10.6
# 45  37          Nicolas Batum   SF   26  POR  71  ...  4.8  1.1  0.6  1.9  1.5   9.4
# 46  38         Jerryd Bayless   PG   26  MIL  77  ...  3.0  0.8  0.2  1.7  2.1   7.8
# 47  39            Aron Baynes    C   28  SAS  70  ...  0.5  0.2  0.3  0.9  2.3   6.6
# 48  40          Kent Bazemore   SG   25  ATL  75  ...  1.0  0.7  0.4  1.0  1.7   5.2
# 49  Rk                 Player  Pos  Age   Tm   G  ...  AST  STL  BLK  TOV   PF   PTS
#
# [50 rows x 30 columns]

# %% [markdown]
# Question 3 (10 points). Understand the data quality: Search a second hand dataset (any dataset) from kaggle or other websites. Describe the data quality problem of the dataset and explain your strtegy to clean the data.

# %%
# Your answer here (no code for this question, write down your answer as detail as possible for the above questions):
'''

Please write you answer here:

Data Quality:The qualitative and quantitaive measurement of the data is considered as data quality.

second Hand dataset from kaggle:
after searching the kaggle for the second hand dataset found the below dataset which contains the stats of all the playes which 
can be compared against to check the data quality and also to imporve it.

https://www.kaggle.com/jacobbaruch/basketball-players-stats-per-season-49-leagues

Data quality Problem:

In the above data that we took to answer the research question. the headings of the data is being repeated and it effects
the quality of the data as it contain the duplicates.

we can eliminate those duplicated by filtering the dataframe with respect to the heading age then all the duplicated will be
seperated then droping them from the data frame cleans the data. and quality of the data improves drastically so, after 
droping the duplicate columns we will be left with 651 rows and using this we can obtains the relations as accurately possible.

'''

final_data1 = final_data.drop(final_data[final_data['Age'] == 'Age'].index)
final_data1
# Out:
#       Rk          Player Pos Age   Tm   G  ...  AST  STL  BLK  TOV   PF   PTS
# 0      1      Quincy Acy  PF  24  NYK  68  ...  1.0  0.4  0.3  0.9  2.2   5.9
# 1      2    Jordan Adams  SG  20  MEM  30  ...  0.5  0.5  0.2  0.5  0.8   3.1
# 2      3    Steven Adams   C  21  OKC  70  ...  0.9  0.5  1.2  1.4  3.2   7.7
# 3      4     Jeff Adrien  PF  28  MIN  17  ...  0.9  0.2  0.5  0.5  1.8   3.5
# 4      5   Arron Afflalo  SG  29  TOT  78  ...  1.7  0.5  0.1  1.5  2.1  13.3
# ..   ...             ...  ..  ..  ...  ..  ...  ...  ...  ...  ...  ...   ...
# 670  490  Thaddeus Young  PF  26  TOT  76  ...  2.3  1.6  0.3  1.5  2.3  14.1
# 671  490  Thaddeus Young  PF  26  MIN  48  ...  2.8  1.8  0.4  1.6  2.4  14.3
# 672  490  Thaddeus Young  PF  26  BRK  28  ...  1.4  1.4  0.3  1.5  2.0  13.8
# 673  491     Cody Zeller   C  22  CHO  62  ...  1.6  0.5  0.8  1.0  2.5   7.6
# 674  492    Tyler Zeller   C  25  BOS  82  ...  1.4  0.2  0.6  0.9  2.5  10.2
#
# [651 rows x 30 columns]

# %% [markdown]
# Question 4 (20 points). Data cleaning: There are two datasets TwADR-L (from Twitter) and AskAPatient (Link: https://zenodo.org/record/55013#.YgU2NN-ZO4T) for medical concept
# normalization. However, the two datasets have serious data quality problems. Please read the introduction of the datasets and clean the two datasets by following the steps in the statement.
#
# In the original dataset, the TwADR-L had 48,057 training, 1,256 validation and 1,427 test examples. The test set (all
# test samples from 10 folds combined) consists of 765 unique phrases and 273 unique classes (medical concepts). The AskAPatient dataset contained 156,652 training, 7,926 validation, and 8,662 test examples. The entire test set (all test samples
# from 10 folds combined) consists of 3,749 unique phrases and 1,035 unique classes (medical concepts). The authors
# randomly split each dataset into ten equal folds, ran 10-fold cross validation and reported the accuracy averaged across the
# ten folds.
#
# We found that, in the original data set, many phrase-label pairs appeared multiple times within the same training data file
# and also across the training and test data sets in the same fold. In the AskAPatient data set, on average 35.82% of the test data overlapped with training data in the same fold. In the Twitter (TwADR-L) dataset, on average 8.62% of the test set had an overlap with the training data in the same fold. Having a large overlap between the training and the test data can potentially
# introduce bias in the model and contribute to high accuracy. It is not unlikely that the high model performance reported in the original paper may be triggered by the the large overlap between the training and test sets.
#
# Therefore to remove the bias, we further cleaned and recreated the training, validation, and test sets such that each
# phrase-label pair appears only once in the entire dataset (either in training, validation or test set).
#
# (1) First, we combined all examples in training, validation and test data from the original data set and then removed all
# duplicate phrase-label pairs (examples that have the same phrase and label pair and appear more than once in training/validation/test datasets). Table II shows the statistics of the new dataset (after removing duplicates). The Twitter data set had 3,157 unique phrase-label pairs and 2,220 unique labels (medical concepts) while 173 phrases had multiple labels (i.e., they were assigned to more than one label). Many concepts had only one example, and the concept that had the most number
# of examples had 36 phrases. On average, each concept had 1.42 examples. The AskAPatient data set had 4,496 unique phrase-label pairs, 1,036 unique labels while 26 phrases had multiple labels. Table III shows examples of phrases that had multiple labels. For example, ‘mad’ can be mapped to ‘anger’ or ‘rage’ and ‘sore’ can be mapped to ‘pain’ or ‘myalgia’.
#
# (2) Second, we remove all concepts that had less than five examples. The statistics of the final data are shown in Table IV.
#
# (3) Third, we divide all examples without multiple labels into random 10 folds such that each unique phrase-label pair
# appears once in one of the 10 test sets. We add the pairs with multiple labels into the training data. This final 10-folds
# dataset is used in all our experiments.
#
# (The original paper can be download on canvas)

# %%
from typing_extensions import final
# You code here (Please add comments in the code):


import glob
import pandas as pd
import numpy as np


#askapatient
ask_df=[]
ask_name=glob.glob=('/content/sample_data/AskaPatient/*.txt')
for f in ask_name:
  ask_df.append(pd.read_csv(f, encoding='ISO-8859-1',sep='\t',header=None))

ask_df=pd.concat(ask_df, ignore_index=True)
ask_df.drop_duplicates(inplace=True,ignore_index=True,keep='first')
ask_df=ask_df.groupby([1]).filter(lambda x : len(x)>=5)

ask_trn= ask_df.groupby([2]).filter(lambda x: len(x)>1)
ask_trn = ask_trn.sample(frac=1)
result = np.array_split(ask_trn, 10)
for i in result:
  print(i,'\n')

ask_tst= ask_df.groupby([2]).filter(lambda x: len(x)==1)
ask_tst = as_tst.sample(frac=1)
result = np.array_split(ask_tst, 10)
for i in result:
  print(i,'\n')


#twitter
nme=glob.glob('/content/sample_data/twADR_l/*.txt')
df=[]

for i in nme:
  data=pd.read_csv(i,sep='\t',header=None,index_col=None)
  df.append(data)

df=pd.concat(df,ignore_index=True)
df.drop_duplicates(inplace=True,ignore_index=True,keep='first')
df=df.groupby([1]).filter(lambda x: len(x)>=5)

df_trn=df.groupby([2]).filter(lambda x: len(x)>1)
df_trn=df_trn.sample(frac=1)

rslt = np.array_split(df_trn, 10)
for i in rslt:
  print(i,'\n')

df_tst=df.groupby([2]).filter(lambda x: len(x)==1)
df_tst=df_tst.sample(frac=1)

rslt =np.array_split(df_tst, 10)
for i in rslt:
  print(i, '\n')
# Out:
# ---------------------------------------------------------------------------
# IsADirectoryError                         Traceback (most recent call last)
# <ipython-input-53-78222021897a> in <module>()
#      12 ask_name=glob.glob=('/content/sample_data/AskaPatient/*.txt')
#      13 for f in ask_name:
# ---> 14   ask_df.append(pd.read_csv(f, encoding='ISO-8859-1',sep='\t',header=None))
#      15
#      16 ask_df=pd.concat(ask_df, ignore_index=True)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     584     kwds.update(kwds_defaults)
#     585
# --> 586     return _read(filepath_or_buffer, kwds)
#     587
#     588
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     480
#     481     # Create the parser.
# --> 482     parser = TextFileReader(filepath_or_buffer, **kwds)
#     483
#     484     if chunksize or iterator:
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#     809             self.options["has_index_names"] = kwds["has_index_names"]
#     810
# --> 811         self._engine = self._make_engine(self.engine)
#     812
#     813     def close(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, engine)
#    1038             )
#    1039         # error: Too many arguments for "ParserBase"
# -> 1040         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1041
#    1042     def _failover_to_python(self):
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/c_parser_wrapper.py in __init__(self, src, **kwds)
#      49
#      50         # open handles
# ---> 51         self._open_handles(src, kwds)
#      52         assert self.handles is not None
#      53
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/parsers/base_parser.py in _open_handles(self, src, kwds)
#     227             memory_map=kwds.get("memory_map", False),
#     228             storage_options=kwds.get("storage_options", None),
# --> 229             errors=kwds.get("encoding_errors", "strict"),
#     230         )
#     231
#
# /usr/local/lib/python3.7/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     705                 encoding=ioargs.encoding,
#     706                 errors=errors,
# --> 707                 newline="",
#     708             )
#     709         else:
#
# IsADirectoryError: [Errno 21] Is a directory: '/'
